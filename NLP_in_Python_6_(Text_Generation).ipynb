# %% [markdown]
# <a href="https://colab.research.google.com/github/NimitBajaj/Semantic-Genre-Classification-of-Comedians/blob/main/NLP_in_Python_6_(Text_Generation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      ladies  gentlemen please welcome   stage ali w...          Ali Wong
# anthony  san francisco  so much so good  be here people...  Anthony Jeselnik
# bill     all right   very much    how are you whats goi...         Bill Burr
# bo       bo burnham inside   comedy special written dir...        Bo Burnham
# dave     this  dave he tells dirty jokes for  living th...    Dave Chappelle
# gabriel  gabriel iglesias legend  fluffy   lively celeb...  Gabriel Iglesias
# hasan    san jose whats upnice  see you whats happening...      Hasan Minhaj
# jim      ladies  gentlemen please welcome   stage mr ji...     Jim Jefferies
# joe      ladies  gentlemen welcome joe roganwhat  fck  ...         Joe Rogan
# john     armed with boyish charm   sharp wit  former sn...      John Mulaney
# louis    introfade  music out lets roll hold there ligh...        Louis C.K.
# maher    bill mahers  anyone else seeing this   sharp u...        Bill Maher
# mike     wow hey  thanks  guys hey seattle nice  see yo...    Mike Birbiglia
# ricky      how you doing great  wow calm down shut  fuc...     Ricky Gervais
# theo     theo von no offense was recorded at  civic the...          Theo Von

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# 'ladies  gentlemen please welcome   stage ali wonghi  welcome   for coming   we are gonna have  get this shit over with cause i have  pee  like ten minutes but  everybody so much for comingum its  very'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''

    # Tokenize the text by word, though including punctuation
    words = text.split(' ')

    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)

    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'ladies': ['', 'go', 'who', 'they', '', 'who'],
#  '': ['gentlemen',
#   '',
#   'stage',
#   'welcome',
#   '',
#   'for',
#   '',
#   'we',
#   'get',
#   'pee',
#   'like',
#   'everybody',
#   'very',
#   'very',
#   'this',
#   'five',
#   'girl',
#   'fuck',
#   'foremost',
#   'their',
#   'girls',
#   'then',
#   'shit',
#   'have',
#   'sixpack',
#   'theres',
#   'light',
#   'potential',
#   'sleep',
#   'sleep',
#   'have',
#   'take',
#   'ambien',
#   'meditation',
#   'calm',
#   'chatter',
#   'regret',
#   'resentment',
#   'them',
#   'sleep',
#   'peace',
#   'get',
#   'get',
#   'fucking',
#   'lot',
#   'men',
#   'men',
#   '',
#   'ghost',
#   'says',
#   'womens',
#   'two',
#   'hpv',
#   'kind',
#   'kind',
#   '',
#   'presence',
#   'wolverine',
#   'turning',
#   'selfhelp',
#   'books',
#   'grey',
#   '',
#   'lifechanging',
#   'tidying',
#   'declutter',
#   'achieve',
#   'my',
#   'success',
#   '',
#   'all',
#   'horrible',
#   'hoarding',
#   '',
#   'center',
#   'all',
#   'my',
#   'hoarding',
#   'hpv',
#   'hoarding',
#   'from',
#   'third',
#   'she',
#   'dictators',
#   'country',
#   'snatch',
#   'third',
#   'handy',
#   'shovel',
#   'running',
#   'communiststhe',
#   'san',
#   'help',
#   'shit',
#   'worst',
#   'my',
#   'fighting',
#   'yelling',
#   'it',
#   '',
#   'climax',
#   'let',
#   '',
#   'texas',
#   'manual',
#   'manual',
#   'calculator',
#   'those',
#   'you',
#   'probably',
#   'it',
#   'buy',
#   'eight',
#   '',
#   'everybody',
#   'future',
#   'tesla',
#   'my',
#   'my',
#   'manual',
#   'she',
#   'i',
#   'clean',
#   'im',
#   'be',
#   'procrastinator',
#   'deepakoprah',
#   'way',
#   'achieve',
#   'successi',
#   'lot',
#   '',
#   'man',
#   'lucky',
#   'lot',
#   'losers',
#   'losers',
#   'lot',
#   'skaters',
#   'grownass',
#   'mattress',
#   '',
#   'kitchen',
#   'outside',
#   'inside',
#   'uh',
#   'my',
#   'i',
#   'i',
#   'that',
#   '',
#   'first',
#   'time',
#   'i',
#   'trap',
#   'i',
#   'fifth',
#   '',
#   'very',
#   'catch',
#   '',
#   'secret',
#   'public',
#   'has',
#   'hipster',
#   'that',
#   'it',
#   'san',
#   'i',
#   'broad',
#   'we',
#   'we–',
#   'next',
#   '',
#   'back',
#   'my',
#   'then',
#   'park',
#   'i',
#   'watched',
#   'middle',
#   'i',
#   'homeless',
#   'asian',
#   'lot',
#   'people',
#   'have',
#   'lot',
#   'opinions',
#   'date',
#   'any',
#   '',
#   'major',
#   'america',
#   'that',
#   'turning',
#   'yoko',
#   'white',
#   'white',
#   '',
#   'wes',
#   'you',
#   'lot',
#   'cool',
#   'recycling',
#   'disturbing',
#   'cool',
#   'its',
#   'white',
#   'white',
#   'that',
#   'all',
#   'that',
#   'money',
#   'just',
#   'then',
#   'colonizer',
#   'be',
#   'your',
#   'advantage',
#   'that',
#   'go',
#   'be',
#   'say',
#   'halfvietnamese',
#   'we',
#   'percent',
#   'our',
#   'built',
#   'his',
#   'time',
#   'i',
#   'sexiest',
#   'sexiest',
#   'neck',
#   '',
#   'dolphin',
#   'slip',
#   'slide',
#   'my',
#   'jewish',
#   'your',
#   'all',
#   'inflamed',
#   'youre',
#   'be',
#   '',
#   'last',
#   'rug',
#   'then',
#   'umami',
#   'i',
#   'huge',
#   'halfjapanese',
#   'im',
#   'halfvietnamese',
#   'halfjungle',
#   'difference',
#   'fancy',
#   'chinese',
#   'japanese',
#   'do',
#   'east',
#   'private',
#   'playing',
#   'rugby',
#   'on',
#   'our',
#   'this',
#   'west',
#   'los',
#   'foremost',
#   'name',
#   'number',
#   'it',
#   'all',
#   'bathroom',
#   'bathroom',
#   'supply',
#   'see',
#   'bleach',
#   '',
#   'grandma',
#   '',
#   'corner',
#   '',
#   'wait',
#   'too',
#   'leave',
#   'emotionally',
#   'private',
#   'i',
#   'backpack',
#   'do',
#   '',
#   'shut',
#   'weekend',
#   'thousand',
#   'your',
#   '',
#   'percent',
#   'shitty',
#   'so',
#   'this',
#   'asian',
#   'wall',
#   'neither',
#   'us',
#   'fuck',
#   'go',
#   'imports',
#   'be',
#   'househim',
#   'i',
#   'i–',
#   'do',
#   'woman',
#   'incept',
#   'idea',
#   'mans',
#   'then',
#   'message',
#   'leave',
#   'its',
#   'go',
#   'find',
#   'new',
#   'start',
#   'whole',
#   'just',
#   'shit',
#   'caves',
#   '',
#   'gets',
#   '',
#   'like',
#   'fuck',
#   'then',
#   'woman',
#   'always',
#   'look',
#   'exact',
#   'my',
#   'send',
#   'him',
#   'man',
#   'pinterest',
#   'men',
#   'saturday',
#   'following',
#   '',
#   'i',
#   'be',
#   'completely',
#   'like',
#   'very',
#   'for',
#   'i',
#   '',
#   'goodness',
#   'my',
#   'my',
#   'coo',
#   'facebook',
#   'she',
#   'sit',
#   'table',
#   'rise',
#   '',
#   'top',
#   'her',
#   'called',
#   'well',
#   'ok',
#   'lie',
#   'fuck',
#   '',
#   'worst',
#   'women',
#   'be',
#   'smart',
#   'continue',
#   'next',
#   'be',
#   'do',
#   'eat',
#   'watch',
#   'have',
#   'then',
#   'show',
#   'be',
#   'secret',
#   'now',
#   'work',
#   'phrase',
#   'lot',
#   'women',
#   'theyre',
#   'lot',
#   'options',
#   'most',
#   'earn',
#   'my',
#   'street',
#   'theyll',
#   'her',
#   '',
#   'genius',
#   'housewife',
#   'boat',
#   'its',
#   'great',
#   'lot',
#   'great',
#   '',
#   'terms',
#   'day',
#   '',
#   'best',
#   'office',
#   '',
#   'office',
#   '',
#   'office',
#   'shit',
#   'their',
#   'seat',
#   'day',
#   'eat',
#   'sadass',
#   'pull',
#   'ration',
#   'desert',
#   'try',
#   'make',
#   'macgyver',
#   'moisten',
#   'then',
#   'digitally',
#   'come',
#   'then',
#   'start',
#   'you',
#   'stall',
#   'youre',
#   'then',
#   'then',
#   'then',
#   'doo',
#   'then',
#   'end',
#   '',
#   'day',
#   'goonies',
#   'velocity',
#   'you',
#   'butt',
#   'make',
#   'doo',
#   'slow',
#   'steady',
#   'brings',
#   'just',
#   'toilet',
#   'let',
#   'reverberate',
#   '',
#   'ends',
#   'their',
#   'podcasts',
#   'toilet',
#   'me',
#   'credence',
#   'my',
#   'toilet',
#   'other',
#   'nerve',
#   'come',
#   'me',
#   'say',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'my',
#   'he',
#   'you',
#   'make',
#   'lot',
#   'same',
#   'privileged',
#   'part',
#   'this',
#   'fuck',
#   'rest',
#   'my',
#   'marry',
#   'promise',
#   'early',
#   'when',
#   'im',
#   'just',
#   '',
#   'turn',
#   'circle',
#   'lot',
#   'myself',
#   'disgusting',
#   'pervert',
#   'gross',
#   'i',
#   'very',
#   'what',
#   'young',
#   'that',
#   'sicker',
#   'sicker',
#   'images',
#   'sicker',
#   'sicker',
#   'internet',
#   'youi',
#   'put',
#   '',
#   'back',
#   'idiot',
#   'posted',
#   'internet',
#   'all',
#   'jewish',
#   '',
#   'universe',
#   'lot',
#   'women',
#   'theyre',
#   '',
#   'pain',
#   '',
#   'pain',
#   'crazy',
#   '',
#   'pain',
#   '',
#   'doo',
#   'dick',
#   'thats',
#   'your',
#   'lies',
#   '',
#   'butt',
#   'i',
#   'her',
#   'do',
#   'because',
#   'different',
#   'my',
#   '',
#   'as',
#   'result',
#   'little',
#   'second',
#   'time♪',
#   'whole',
#   'mine',
#   'help',
#   'conqueror',
#   'now',
#   'treat',
#   'little–',
#   'little',
#   '',
#   'tushtush',
#   'little',
#   'youll',
#   'lot',
#   'resistance',
#   'man',
#   'lot',
#   'no',
#   'succeed',
#   'they',
#   'i',
#   'you',
#   'look',
#   '',
#   'mans',
#   'its',
#   'first',
#   'show',
#   'magical',
#   'his',
#   'then',
#   'woman',
#   'his',
#   'lord',
#   '',
#   'rim',
#   'unfortunately',
#   'spank',
#   'what',
#   'thats',
#   'abuse',
#   'most',
#   'be',
#   'most',
#   'bed',
#   'woman',
#   'control',
#   'time',
#   'be',
#   'control',
#   'be',
#   'control',
#   'do',
#   'im',
#   'being',
#   'boss',
#   'boss',
#   'time',
#   '',
#   'bedroom',
#   'boss',
#   'real',
#   'i',
#   'has',
#   'big',
#   'her',
#   '',
#   'ban',
#   'word',
#   'elementary',
#   'her',
#   'use',
#   'word',
#   'saying',
#   'say',
#   '',
#   'very',
#   'saying',
#   'little',
#   'right',
#   'like',
#   'housewife',
#   'get',
#   'like',
#   'certain',
#   '',
#   'point',
#   'couple',
#   'whole',
#   'kind',
#   'income',
#   'dude',
#   'take',
#   'stroll',
#   'sidewalk',
#   'quarter',
#   'just',
#   'princessi',
#   'sisters',
#   'vietnam',
#   '',
#   'half',
#   'unusual',
#   'see',
#   'female',
#   'think',
#   'one',
#   'them',
#   'case',
#   'baby',
#   'week',
#   'theyll',
#   'little',
#   'shit',
#   'boring',
#   'all',
#   '',
#   'audience',
#   'their',
#   '',
#   'sudden',
#   'mom',
#   'at',
#   'fucking',
#   'wearing',
#   'frozen',
#   'heal',
#   'babys',
#   'me',
#   'lot',
#   'my',
#   'lot',
#   'famous',
#   'kid',
#   'they',
#   'kid',
#   'youre',
#   'dream',
#   'point',
#   '',
#   'ultimate',
#   'lot',
#   'my',
#   'me',
#   'kid',
#   'kid',
#   'world',
#   'just',
#   'rest',
#   'your',
#   'asian',
#   'therefore',
#   'live',
#   'billion',
#   'turtle',
#   'galapagos',
#   'phrase',
#   'women',
#   'you',
#   'die',
#   'ignore',
#   'right',
#   'uturn',
#   'oturn',
#   'car',
#   'hide',
#   '',
#   'mess',
#   'side',
#   'nowhere',
#   'then',
#   'hood',
#   'alert',
#   'their',
#   'have',
#   'keep',
#   '',
#   'going',
#   'full',
#   'century',
#   'go',
#   'she',
#   'so',
#   'her',
#   'not',
#   'movie',
#   'be',
#   'when',
#   'support',
#   'be',
#   'those',
#   'living',
#   'fuck',
#   '',
#   'park',
#   'free',
#   'their–',
#   'protect',
#   'sun',
#   '',
#   'contest',
#   'see',
#   '',
#   'sun',
#   'tupac',
#   'biggie',
#   'longevityi',
#   'have',
#   'kid',
#   'which',
#   'not',
#   'show',
#   'change',
#   'it–',
#   'it',
#   '',
#   'my',
#   'not',
#   'be',
#   'years',
#   'your',
#   'time',
#   'time',
#   'peace',
#   'there',
#   'between',
#   'bubble',
#   'mother',
#   '',
#   'i',
#   'get',
#   'little',
#   'science',
#   'get',
#   '',
#   'lot',
#   'that',
#   'most',
#   'my',
#   'i',
#   'smokers',
#   'i',
#   'take',
#   'push',
#   'then',
#   'boat',
#   'front',
#   'my',
#   'then',
#   'pill',
#   'melt',
#   'i',
#   'act',
#   'then',
#   'side',
#   '',
#   'progesterone',
#   'find',
#   'discretely',
#   'conference',
#   'then',
#   'urge',
#   'immediately',
#   'be',
#   'smell',
#   'sniff',
#   'sandwich',
#   'when',
#   'way',
#   'smell',
#   'protect',
#   '',
#   'hood',
#   'see',
#   'doctor',
#   'i',
#   'have',
#   'kid',
#   'lot',
#   'people',
#   'lot',
#   'fuckin',
#   'your',
#   'ok',
#   'your',
#   '',
#   'youve',
#   'get',
#   'while',
#   'eggs',
#   'i',
#   '',
#   'month',
#   'outside',
#   'that',
#   'save',
#   'be',
#   'as',
#   'rapey',
#   'kraken',
#   'they',
#   'bunch',
#   'angry',
#   'dictatorship',
#   'um',
#   'most',
#   '',
#   'time',
#   'see',
#   'smiley',
#   'ovulation',
#   'id',
#   'i',
#   'hand',
#   '',
#   'time',
#   'he',
#   'such',
#   'close',
#   'shut',
#   'image',
#   'your',
#   'their',
#   'instead',
#   'back',
#   'their',
#   'fine',
#   'see',
#   'expression',
#   'fuck',
#   'then',
#   'finish',
#   'indication',
#   'very',
#   'man',
#   'about',
#   'finish',
#   'zombie',
#   'then',
#   '',
#   'eye',
#   'remember',
#   'come',
#   'then',
#   'hold',
#   'i',
#   'shit',
#   'him',
#   'do',
#   'this',
#   'atlanta',
#   'then',
#   'make',
#   'that',
#   'me',
#   'be',
#   '',
#   'be',
#   'be',
#   '',
#   'half',
#   'miscarriage',
#   'very',
#   '',
#   'lot',
#   'women',
#   'their',
#   'flip',
#   'terrible',
#   'girl',
#   'youll',
#   'women',
#   'miscarriage',
#   'i',
#   'third',
#   'when',
#   'pair',
#   'shoes',
#   'everything',
#   'reason',
#   'very',
#   '',
#   'doctor',
#   'me',
#   'i',
#   'then',
#   '',
#   'heartbeat',
#   'i',
#   'lord',
#   'mysterious',
#   'size',
#   'poppy',
#   'twins',
#   'most',
#   'miscarriage',
#   'front',
#   'me',
#   'toilet',
#   'i',
#   'whole',
#   'he',
#   'i',
#   'held',
#   'month',
#   'got',
#   'do',
#   'fuck',
#   'do',
#   'days',
#   'see',
#   'bike',
#   'craigslist',
#   'i',
#   'days',
#   'marriage',
#   'childbirth',
#   'hire',
#   'doula',
#   'you',
#   'doula',
#   'thats',
#   'white',
#   'keyser',
#   'pain',
#   'lot',
#   'women',
#   'freak',
#   'freak',
#   'table',
#   'it',
#   'my',
#   'cleanse',
#   'labor',
#   'your',
#   'assist',
#   '',
#   'labor',
#   ...],
#  'gentlemen': ['please'],
#  'please': ['welcome', 'no', 'hurry', 'look'],
#  'welcome': ['', ''],
#  'stage': ['ali', ''],
#  'ali': ['wonghi', 'you', 'we', 'why', 'did', 'wong'],
#  'wonghi': [''],
#  'for': ['coming',
#   'comingum',
#   'me',
#   'me',
#   'me',
#   'my',
#   'fashion',
#   'warmth',
#   'marriage',
#   'them',
#   '',
#   '',
#   '',
#   'four',
#   'five',
#   'five',
#   '',
#   'us',
#   'fresh',
#   'but',
#   'me',
#   'them',
#   'his',
#   '',
#   'once',
#   '',
#   'thats',
#   'all',
#   '',
#   'me',
#   'me',
#   'me',
#   '',
#   'them',
#   'granted',
#   '',
#   '',
#   'me',
#   '',
#   '',
#   '',
#   'coming',
#   '',
#   'playing',
#   'being',
#   'doing'],
#  'coming': ['', 'you', '', 'true'],
#  'we': ['are',
#   'were',
#   'were',
#   'were',
#   'had',
#   'had',
#   'had',
#   'were',
#   'were',
#   'spend',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'pay',
#   'do',
#   'eat',
#   'eat',
#   'eat',
#   'do',
#   'are',
#   'have',
#   'got',
#   'as',
#   'had',
#   'could',
#   'dont',
#   'better',
#   'could',
#   'could',
#   'have',
#   'had',
#   'walk',
#   'just',
#   'all',
#   'dont',
#   'live',
#   'wouldnt',
#   'got',
#   'got',
#   'bought',
#   'die'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   '',
#   '',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'you',
#   'ceos',
#   'never',
#   'like',
#   '',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin',
#   '',
#   'you'],
#  'gonna': ['have',
#   'turn',
#   'die',
#   'overtake',
#   'have',
#   'trap',
#   'propose',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live',
#   'tell',
#   'happen',
#   'have',
#   'become–',
#   'disappear',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be',
#   'recycle',
#   'burn',
#   'be',
#   'poop',
#   'be'],
#  'have': ['',
#   '',
#   '',
#   'insomnia',
#   '',
#   'their',
#   'hpv',
#   'it',
#   'hpv',
#   'hpv',
#   'one',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   '',
#   'your',
#   '',
#   '',
#   'executive',
#   'some',
#   '',
#   '',
#   '',
#   'had',
#   'children',
#   'any',
#   '',
#   '',
#   '',
#   'sex',
#   '',
#   'had',
#   '',
#   '',
#   ''],
#  'get': ['this',
#   'it',
#   'it',
#   'rid',
#   'it',
#   '',
#   '',
#   '',
#   '',
#   'very',
#   'very',
#   '',
#   '',
#   'my',
#   'sicker',
#   'sicker',
#   'really',
#   '',
#   '',
#   'all',
#   'us',
#   '',
#   'pregnant',
#   'pregnant',
#   'up',
#   'into',
#   'older',
#   'as',
#   '',
#   'pregnant',
#   'pregnant',
#   'that',
#   'my',
#   'pregnant',
#   'huge',
#   'dark',
#   'big–',
#   'big',
#   'all',
#   'pregnant'],
#  'this': ['shit',
#   'year',
#   'doctor',
#   'shit',
#   'shit',
#   'calculator',
#   'judy',
#   '',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   '',
#   'restaurant',
#   'restaurant',
#   'hippydippy',
#   'sneaking',
#   'wacky',
#   'dude',
#   'dude',
#   'bitch',
#   'huge',
#   'shit',
#   'conversation',
#   '',
#   'fucking',
#   'relatable',
#   '',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream'],
#  'shit': ['over',
#   '',
#   '',
#   'around',
#   'around',
#   'dont',
#   'up',
#   '',
#   'my',
#   'on',
#   'like',
#   'we',
#   'outta',
#   '',
#   '',
#   '',
#   'too',
#   'was',
#   'together',
#   'togethermy',
#   'i',
#   'youre',
#   'turns',
#   'its',
#   'they',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore',
#   'that'],
#  'over': ['with', 'again', 'again', 'by', 'his'],
#  'with': ['cause',
#   '',
#   'where',
#   'your',
#   'all',
#   'these',
#   '',
#   '',
#   '',
#   'somebody',
#   '',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him',
#   'him',
#   'me',
#   'their',
#   '',
#   'which',
#   'me',
#   '',
#   'eyelashes',
#   'my',
#   '',
#   'male',
#   'your',
#   'no',
#   'me',
#   'it',
#   'you',
#   'intention',
#   'me',
#   'your',
#   'my'],
#  'cause': ['i',
#   'im',
#   'it',
#   'it',
#   'he',
#   'i',
#   'were',
#   'my',
#   'youre',
#   'when',
#   'its',
#   'if',
#   'her',
#   'she',
#   'its',
#   'you',
#   'i',
#   'i'],
#  'i': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'dont',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am',
#   'turn',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew',
#   'was',
#   'dropped',
#   'was',
#   'just',
#   'dont',
#   'get',
#   'mean',
#   'just',
#   'could',
#   'could',
#   'think',
#   'was',
#   'dont',
#   'did',
#   'go',
#   'have',
#   'read',
#   'was',
#   'pee',
#   'need',
#   'are',
#   'had',
#   'just',
#   'had',
#   'just',
#   'wanted',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'waspeople',
#   'did',
#   'dont',
#   'dont',
#   'straight',
#   'dont',
#   'do',
#   'dont',
#   'dont',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'saw',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said',
#   'do',
#   'really',
#   'dont',
#   'got',
#   'got',
#   'think',
#   'started',
#   'was',
#   'went',
#   'dont',
#   'just',
#   'gotta',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was',
#   'got',
#   'just',
#   'dont–',
#   'dont',
#   'dont',
#   'like',
#   'respect',
#   'know',
#   'dont',
#   'dont',
#   'also',
#   'just',
#   'cant',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want',
#   'wanna',
#   'dont',
#   'am',
#   'dare',
#   'just',
#   'identify',
#   'dont',
#   'was',
#   'won',
#   'was',
#   'really',
#   'changed',
#   'changed',
#   'get',
#   'need',
#   'dont',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'know',
#   'slime',
#   'slime',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'dont',
#   'had',
#   'cant',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'dont',
#   'was',
#   'lost',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'cant',
#   'can',
#   'am',
#   'am',
#   'didnt',
#   'cant',
#   'get',
#   'do',
#   'like',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didnt',
#   'didnt',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   '–',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'dont'],
#  'pee': ['', 'i', 'on'],
#  'like': ['ten',
#   'shit',
#   '',
#   'fifty',
#   '',
#   '',
#   'this',
#   '',
#   'you',
#   'but',
#   'oh',
#   'oh',
#   'all',
#   'we',
#   'hey',
#   'wassup',
#   'hey',
#   'where',
#   'at',
#   'oh',
#   'you',
#   '',
#   'youre',
#   'voting',
#   'that',
#   'im',
#   'i',
#   'you',
#   'hold',
#   'making',
#   '',
#   'i',
#   'loofah',
#   'responsibility',
#   'host',
#   'filipino',
#   'its',
#   'its',
#   'private',
#   '',
#   '',
#   'that',
#   'freerange',
#   '',
#   'we',
#   'we',
#   'oh',
#   'im',
#   'shut',
#   'oh',
#   'you',
#   'very',
#   'were',
#   'we',
#   'but',
#   'look',
#   'that',
#   'youre',
#   'wiping',
#   'oh',
#   'its',
#   'you',
#   'hey',
#   'why',
#   'mrs',
#   'uh',
#   'oh',
#   'youre',
#   'i',
#   'oh',
#   'im',
#   '',
#   'it',
#   'that',
#   'hes',
#   'youre',
#   'yes',
#   '',
#   'i',
#   'become',
#   '',
#   '',
#   'guys',
#   'thats',
#   'ali',
#   'yeah',
#   'why',
#   'yeah',
#   '',
#   'yeah',
#   'oh',
#   'im',
#   '',
#   'im',
#   'skittles',
#   '',
#   'everything',
#   'oh',
#   'only',
#   'were',
#   'release',
#   '',
#   'we',
#   'ok',
#   'they',
#   'hey',
#   'oh',
#   'uh',
#   'losing',
#   'no',
#   'yes',
#   'you',
#   'yeah',
#   'that',
#   'this',
#   'i',
#   '',
#   '',
#   'fingers',
#   'you',
#   'whoppers',
#   '',
#   'when',
#   'really',
#   'why',
#   'way'],
#  'ten': ['minutes', 'gallons', 'times'],
#  'minutes': ['but'],
#  'but': ['',
#   'fuck',
#   'i',
#   'my',
#   'i',
#   'he',
#   'sometimes',
#   'ali',
#   'i',
#   'its',
#   'dont',
#   'i',
#   'i',
#   'im',
#   'my',
#   'what',
#   'hes',
#   'mostly',
#   'im',
#   'its'],
#  'everybody': ['so', 'has', 'has', 'has', 'thought', 'doesnt', 'thought'],
#  'so': ['much',
#   'basically',
#   'you',
#   'emotional',
#   'emotional',
#   'i',
#   'much',
#   'vulnerable',
#   'smooth',
#   'were',
#   'he',
#   'its',
#   'you',
#   'youre',
#   'that',
#   'good',
#   'i',
#   'many',
#   'that',
#   'that',
#   'when',
#   '',
#   'that',
#   '',
#   'motherfucker',
#   'do',
#   'now',
#   'annoying',
#   'i',
#   'that',
#   'embarrassing',
#   'lonely',
#   'juicy',
#   'my',
#   'then',
#   'then',
#   'hot',
#   'that',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'much',
#   'you',
#   'little',
#   'little',
#   'supportive',
#   'i',
#   'that',
#   'that',
#   'that',
#   'as'],
#  'much': ['for',
#   'better',
#   'chemistry',
#   'i',
#   'shittier',
#   'netflix',
#   'for',
#   'resentment'],
#  'comingum': ['its'],
#  'its': ['',
#   'been',
#   'like',
#   'ok',
#   'coming',
#   'undetectable',
#   'really',
#   '',
#   'too',
#   'very',
#   'hot',
#   'amazing',
#   'what',
#   'like',
#   'so',
#   'all',
#   'its',
#   'different',
#   'authentic',
#   'not',
#   'funny',
#   'too',
#   '',
#   '',
#   'probably',
#   'basically',
#   'been',
#   'very',
#   'because',
#   'ok',
#   'like',
#   'like',
#   '',
#   'because',
#   'sexist',
#   'very',
#   'so',
#   '',
#   '',
#   'what',
#   'lonely',
#   '',
#   'very',
#   'all',
#   'too',
#   'easter',
#   'like',
#   'go',
#   'not',
#   'because',
#   'when',
#   'super',
#   'whatevs',
#   'toll',
#   'different',
#   'not',
#   'straight',
#   'neosporinso'],
#  'very': ['exciting',
#   'exciting',
#   'helpful',
#   'lucky',
#   'unusual',
#   'confusing',
#   'you',
#   'picturesque',
#   'you',
#   'underrated',
#   'well',
#   'surprised',
#   'soft',
#   'nurturing',
#   'domestic',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing',
#   'clinical',
#   'universal',
#   'grateful',
#   'common',
#   'early',
#   'much',
#   'very',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'let',
#   'yeah',
#   '',
#   'was',
#   'getting',
#   'jobs',
#   'which',
#   'housewives',
#   'every',
#   'like',
#   'long',
#   'looks',
#   'this',
#   'since',
#   'long',
#   'on'],
#  'me': ['its',
#   'i',
#   'that',
#   'tony',
#   'that',
#   '',
#   'something',
#   'hes',
#   'off',
#   'feel',
#   '',
#   '',
#   'feel',
#   '',
#   '',
#   'tell',
#   'cause',
#   'about',
#   'with',
#   '',
#   'when',
#   'anymore',
#   '',
#   '',
#   '',
#   'this',
#   'on',
#   'when–',
#   'this',
#   '',
#   'ok',
#   'i',
#   'enough',
#   'you',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'because',
#   'see',
#   '',
#   'but',
#   'company',
#   'when',
#   'i',
#   'when',
#   'anymore',
#   'like',
#   'extremely',
#   'because',
#   '',
#   'thats',
#   'oh',
#   'while',
#   '',
#   '',
#   '',
#   'out',
#   'out',
#   '',
#   'oh',
#   'im',
#   'im',
#   'i',
#   'money',
#   '',
#   'for',
#   'out',
#   'oh',
#   'with',
#   'how',
#   'oh'],
#  'been': ['',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   '',
#   'run',
#   'eating',
#   'trying',
#   'ali'],
#  'year': ['for', 'yes', 'uh', 'i', 'ive', 'i', 'i'],
#  'turned': [''],
#  'yes': ['', 'yes', 'thats', 'yes', 'yes', 'i', 'i', 'because', ''],
#  'five': ['people', 'years', 'years'],
#  'people': ['i',
#   'inside',
#   'are',
#   'its',
#   'all',
#   'dont',
#   'until',
#   'doing',
#   'like',
#   'i',
#   'thats',
#   'were',
#   'praise',
#   'dont',
#   'will'],
#  'appreciate': ['that'],
#  'that': ['uh',
#   'im',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'i',
#   'im',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'im',
#   'will',
#   '',
#   'at',
#   'he',
#   'your',
#   'has',
#   'store',
#   'beard',
#   'shit',
#   '',
#   'privilege',
#   'entitlement',
#   'for',
#   'you',
#   'uh',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'seems',
#   'he',
#   'youre',
#   'i',
#   'i',
#   'so',
#   'hed',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'well',
#   'fucking',
#   'housewife',
#   'bitch',
#   'horrible',
#   'they',
#   'oneply',
#   'office',
#   'they',
#   'your',
#   '',
#   'no',
#   'shit',
#   'you',
#   'dont',
#   'i',
#   'yyou',
#   'if',
#   'im',
#   'hes',
#   '',
#   'you',
#   'if',
#   'then',
#   'theyre',
#   'fear',
#   'shit',
#   'fear',
#   'he',
#   'we',
#   'im',
#   'i',
#   'woman',
#   'now',
#   'whole',
#   '',
#   'was',
#   'was',
#   'babys',
#   'everybody',
#   'its',
#   'came',
#   'shes',
#   'cause',
#   '',
#   'you',
#   'snailtrail',
#   '',
#   'my',
#   'were',
#   'it',
#   'its',
#   'tell',
#   'i',
#   'when',
#   'means',
#   'they',
#   'they',
#   'day',
#   'says',
#   'that',
#   'stupidass',
#   'i',
#   'harvard',
#   'theyre',
#   'im',
#   'i',
#   'shit',
#   '',
#   'blows',
#   'youre',
#   'you–',
#   'that',
#   'happens',
#   'he',
#   'hes',
#   'goes',
#   'i',
#   'they',
#   '',
#   '',
#   'im',
#   'my'],
#  'uh': ['i',
#   'this',
#   'hes–',
#   'between',
#   'you',
#   'we',
#   'youre',
#   'im',
#   'mmm',
#   'yeah',
#   'two'],
#  'can': ['tell',
#   'also',
#   'i',
#   'i',
#   'never',
#   'you',
#   'be',
#   'tell',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk',
#   'comfortably',
#   'tell',
#   'just',
#   'think',
#   'i',
#   'i',
#   'i',
#   'already',
#   'really',
#   'you',
#   'you',
#   'already',
#   'see',
#   'find'],
#  'tell': ['that',
#   'that',
#   'first',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'but',
#   'you',
#   'because',
#   'you'],
#  'im': ['getting',
#   'straight',
#   'jealous',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   '',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   '',
#   'gonna',
#   'absorbing',
#   'like',
#   'halfchinese',
#   'halfchinese',
#   'just',
#   '',
#   'very',
#   'like',
#   'done',
#   'done',
#   'not',
#   '–',
#   '',
#   '',
#   '',
#   'scared',
#   '',
#   'going',
#   'like',
#   'gonna',
#   'gonna',
#   'tired',
#   '',
#   '',
#   'talking',
#   'talking',
#   'striving',
#   '',
#   '',
#   'guaranteed',
#   'gonna',
#   'like',
#   'still',
#   'just',
#   'older',
#   'not',
#   'just',
#   'only',
#   'only',
#   'gonna',
#   '',
#   '',
#   'from',
#   'very',
#   'going',
#   'all',
#   'busy',
#   '',
#   'not',
#   '',
#   'fucked',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older', 'older', 'busy', 'massages'],
#  'older': ['because', 'because', 'its', 'when'],
#  'because': ['now',
#   '',
#   'its',
#   'my',
#   'my',
#   'you',
#   'what',
#   'according',
#   'before',
#   'i',
#   'usually',
#   'being',
#   'hes',
#   'hes',
#   'i',
#   'you',
#   'i',
#   'you',
#   'i',
#   '',
#   'he',
#   'you',
#   'theyre',
#   'were',
#   'im',
#   '',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'im',
#   'were',
#   'uh',
#   'when',
#   'theyre',
#   'theyre',
#   'then',
#   '',
#   'were',
#   'last',
#   'when',
#   '',
#   'i',
#   'if',
#   'my–',
#   'he'],
#  'now': ['when',
#   'has',
#   'crush',
#   'for',
#   'were',
#   'oh',
#   'but',
#   'if',
#   'because',
#   'instead',
#   '',
#   'if'],
#  'when': ['i',
#   'they',
#   '',
#   'youre',
#   'she',
#   'we',
#   'you',
#   'you',
#   'really',
#   'i',
#   'youre',
#   '',
#   'i',
#   'you',
#   'i',
#   'our',
#   'you',
#   'we',
#   'i',
#   'i',
#   'i',
#   'i',
#   'you',
#   'he',
#   'i',
#   'that',
#   'ive',
#   'you',
#   'youre',
#   'they',
#   'i',
#   'im',
#   'i',
#   'i',
#   'my',
#   'you',
#   'trying',
#   'i',
#   'everything',
#   'i',
#   'can',
#   'can',
#   'can',
#   '–',
#   'youre',
#   '',
#   'its',
#   'it',
#   'they',
#   'i',
#   'somebody',
#   'somebody',
#   'he',
#   '',
#   'they',
#   'they',
#   'youre',
#   'they',
#   'i',
#   'i',
#   'theyre',
#   'youre',
#   'you',
#   'he',
#   'you',
#   'i',
#   'it',
#   'its',
#   'its'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   '',
#   '',
#   '',
#   'how',
#   'that',
#   'whos',
#   '',
#   '',
#   '',
#   'two',
#   '',
#   'beyoncé',
#   'how',
#   'how',
#   'if',
#   'like',
#   'me'],
#  'an': ['', 'atm', 'impression', 'investment'],
#  'girl': ['my', 'because', 'when'],
#  'my': ['automatic',
#   'doctor',
#   'body',
#   'kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life',
#   'generation',
#   'time',
#   'mom',
#   'optimum',
#   'husband',
#   'league',
#   'god',
#   'god',
#   'part',
#   'generation',
#   'volvo',
#   'pussy',
#   'god',
#   'husband',
#   'god',
#   'bed',
#   'husband',
#   'god',
#   'pinterest',
#   'best',
#   'wedding',
#   'husband',
#   'personality',
#   'heart',
#   'financial',
#   'friends',
#   'coworkers',
#   'toilet',
#   'fingers',
#   'coworkers',
#   'coworkers',
#   'shit',
#   'husband',
#   'life',
#   'destiny',
#   'last',
#   'mom',
#   'dad',
#   'grandma',
#   '',
#   'god',
#   'god',
#   'husband',
#   'asianamerican',
#   'female',
#   'friends',
#   'husband',
#   'mind',
#   'mind',
#   'god',
#   'face',
#   'toyota',
#   'mom',
#   'husband',
#   'destiny',
#   'body',
#   'pussy',
#   'god',
#   'fault',
#   '',
#   'uterus',
#   'progesterone',
#   'writing',
#   'coworkers',
#   'underwear',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers',
#   'fingers',
#   'fingers',
#   'husband',
#   'god',
#   'husband',
#   'face',
#   'god',
#   'mom–',
#   'sixweek',
#   'god',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband',
#   'husband',
#   'doctors',
#   'god',
#   'blood',
#   'husband',
#   'nipples',
#   'pussys',
#   'pussys',
#   'bodys',
#   'husband',
#   'league',
#   'god',
#   'dreams',
#   'beautiful',
#   'hardearned',
#   'ass'],
#  'automatic': ['thought'],
#  'thought': ['', 'it', 'they', 'it'],
#  'fuck': ['you',
#   'you',
#   'you',
#   'they',
#   'up',
#   'down',
#   'one',
#   'they',
#   'him',
#   'up',
#   'i'],
#  'you': ['fuck',
#   'i',
#   'but',
#   'cause',
#   'dont',
#   'go',
#   'go',
#   'dont',
#   '',
#   'can',
#   'never',
#   'better',
#   'under',
#   'never',
#   'might',
#   'die',
#   'wanna',
#   'wanna',
#   'gotta',
#   'homeless',
#   '',
#   'drop',
#   'know',
#   'go',
#   'know',
#   'feel',
#   'feel',
#   'know',
#   'feel',
#   'know',
#   'about',
#   '',
#   'know',
#   'know',
#   'right',
#   'knowbut',
#   'get',
#   'get',
#   'like',
#   'dont',
#   'knowmy',
#   'guys',
#   'know',
#   'mess',
#   'guys',
#   'know',
#   'can',
#   'can',
#   'eat',
#   'queef',
#   'know',
#   'gotta',
#   'know',
#   'marry',
#   'something',
#   'would',
#   'dont',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry',
#   'never',
#   'dare',
#   'know',
#   'deep',
#   'need',
#   'need',
#   'dont',
#   'not',
#   'guys',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'tell',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know',
#   'aint',
#   'now',
#   'have',
#   'gotta',
#   'gotta',
#   'dont',
#   'gotta',
#   'put',
#   'know',
#   'havent',
#   'only',
#   'know',
#   'stick',
#   'know',
#   'just',
#   'as',
#   'knowmy',
#   'ok',
#   'all',
#   'know',
#   'right',
#   'respect',
#   'need',
#   'know',
#   'know',
#   'what',
#   'be',
#   'so',
#   'have',
#   'know',
#   'know',
#   'know',
#   'guys',
#   'theres–',
#   'know',
#   'gonna',
#   'just',
#   'knowanother',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'knowi',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'could',
#   'i',
#   'ghostbustersi',
#   'scratch',
#   'can',
#   'urgently',
#   'cause',
#   'gotta',
#   'need',
#   'guys',
#   'do',
#   'pee',
#   'when',
#   'when',
#   '',
#   'know',
#   'that–',
#   'look',
#   'watch',
#   'know',
#   'know',
#   'know',
#   'push',
#   'push',
#   'push',
#   'just',
#   'think',
#   'boom',
#   'wash',
#   'water',
#   'makin',
#   'change',
#   'about',
#   'get',
#   'know',
#   'know',
#   'you',
#   'you',
#   'owe',
#   'my',
#   'see',
#   'know',
#   'know',
#   'think'],
#  'dont': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'ever',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'i',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'tell',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'try',
#   'your',
#   'wanna',
#   'wanna',
#   'worry',
#   'cheat',
#   'i',
#   'no',
#   'wanna',
#   'kill',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack',
#   'die',
#   'die',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'feel',
#   'tell',
#   'work'],
#  'even': ['know', 'know', 'accidentally', 'effective', 'have', 'come'],
#  'know': ['you',
#   'what',
#   'that',
#   'when',
#   'where',
#   'what',
#   'when',
#   'that',
#   'wear',
#   'whats',
#   'because',
#   'you',
#   'white',
#   'its',
#   'just',
#   'why',
#   'oohwee',
#   '',
#   'learning',
#   'anything',
#   'what',
#   'i',
#   'that',
#   'maybe',
#   'how',
#   'how',
#   'you',
#   'squeeze',
#   'its–',
#   'that',
#   'freaked',
#   'i',
#   '',
#   'especially',
#   'i',
#   'you',
#   'like',
#   'i',
#   'i',
#   'what',
#   'youve',
#   'what',
#   'if',
#   'whats',
#   '',
#   '',
#   'why',
#   'whats',
#   '',
#   'what',
#   '',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'i–',
#   'your',
#   'that',
#   'that',
#   'they',
#   '',
#   'i–'],
#  'straight': ['up', 'up', 'up'],
#  'up': ['jealous',
#   'hpv',
#   'yes',
#   'your',
#   'when',
#   '',
#   'on',
#   'with',
#   '',
#   'afterwards',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   '',
#   'fine',
#   'dont',
#   'about',
#   'dont',
#   '',
#   '',
#   '',
#   '',
#   'with',
#   'you',
#   'so',
#   'there',
#   'on',
#   'shes',
#   '',
#   'myself',
#   '',
#   'from',
#   'your',
#   '',
#   'soldier'],
#  'jealous': ['im', 'first'],
#  'first': ['',
#   'met',
#   'thing',
#   'dates',
#   '',
#   'passively',
#   'youll',
#   'lady',
#   'old',
#   'webmdwhen',
#   'home'],
#  'foremost': ['', 'by'],
#  'their': ['metabolism',
#   'feet',
#   'whole',
#   'house',
#   'communist',
#   'shit',
#   'doo',
#   'hallways',
#   'ipad',
#   'eyebrows',
#   'prostate',
#   'fame',
#   'existence',
#   'bigass',
#   'darth',
#   'archnemesis',
#   '',
#   'eyes',
#   'eyes',
#   'eyes',
#   'head',
#   'eyelids',
#   'face',
#   '',
#   'husbands'],
#  'metabolism': ['because'],
#  'girls': ['they'],
#  'they': ['could',
#   'take',
#   'got',
#   'put',
#   'go',
#   'just',
#   'dont',
#   'dont',
#   'have',
#   'dont',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'mean',
#   'ruined',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'purposely',
#   'try',
#   'dont',
#   'dont',
#   'dont',
#   'want',
#   'dont',
#   'can',
#   'can',
#   'wantyou',
#   'say',
#   'would',
#   'wax',
#   'do',
#   'get',
#   'like',
#   'just',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'dont',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'can',
#   'just',
#   'make',
#   'watch',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldnt',
#   'go',
#   'were',
#   'tried',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   '',
#   'crush',
#   'kill',
#   'like',
#   'black',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'lets',
#   'put',
#   'felt',
#   'wanted',
#   'sneak',
#   'give',
#   'give',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'choke',
#   'waiting',
#   'keep',
#   'try',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'i',
#   'scratch',
#   'vacuum',
#   'come',
#   'give',
#   'got',
#   '',
#   'twerk',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like', 'glutenfree', 'all', 'that', 'it', 'snacks', '', 'bananas'],
#  'then': ['they',
#   'when',
#   'after',
#   'also',
#   'asian',
#   'if',
#   'afterwards',
#   'all',
#   'it',
#   'i',
#   'you',
#   'you',
#   'your',
#   'if',
#   'it',
#   'you',
#   'on',
#   'i',
#   'at',
#   'at',
#   '',
#   'i',
#   'resist',
#   'he',
#   'when',
#   'because',
#   'i',
#   'i',
#   'she',
#   'you',
#   'i',
#   'we',
#   'we'],
#  'take': ['', '', 'these', '', 'these', 'its'],
#  'sixpack': ['right'],
#  'right': ['they',
#   'they',
#   'thats',
#   'so',
#   'how',
#   'ali',
#   'there',
#   'now',
#   'we',
#   'because',
#   '',
#   'you',
#   'im',
#   'moment',
#   'turn–',
#   'cause',
#   'there',
#   'after',
#   'ive'],
#  'got': ['thatthat',
#   'so',
#   'married',
#   'no',
#   '',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married',
#   '',
#   'married',
#   '',
#   'no',
#   'bit',
#   'him',
#   'him',
#   'married',
#   'pregnant'],
#  'thatthat': ['beautiful'],
#  'beautiful': ['inner', 'harvardeducated'],
#  'inner': ['thigh', 'peace', 'evil'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they', 'my', 'i', '', 'he', '', 'i', 'they', 'im', 'if'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['', 'you', 'now', 'theyll', '', 'when', ''],
#  'theres': ['that', 'this', 'multiple', 'like', 'nothing'],
#  'huge': ['gap', 'unspoken', 'sitdown', 'bear', ''],
#  'gap': ['here'],
#  'here': ['with', '', 'you'],
#  'light': ['', 'completely'],
#  'potential': ['just', 'why'],
#  'radiating': ['throughand'],
#  'throughand': ['then'],
#  'go': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'home',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   '',
#   'bald',
#   '',
#   'time',
#   'through',
#   ''],
#  'sleep': ['they', 'right', ''],
#  'insomnia': ['yet'],
#  'yet': ['they', 'they', 'you', 'youre', ''],
#  'what': ['its',
#   'that',
#   'your',
#   'that',
#   'it',
#   'love',
#   '',
#   'i',
#   'happens',
#   'youre',
#   'he',
#   '',
#   'im',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'i',
#   'that',
#   ''],
#  'ambien': ['or'],
#  'or': ['download',
#   'i',
#   'youre',
#   'you',
#   'for',
#   'something',
#   'whatever',
#   'something'],
#  'download': [''],
#  'meditation': ['oasis', 'retreats'],
#  'oasis': ['podcast'],
#  'podcast': [''],
#  'calm': [''],
#  'chatter': [''],
#  'regret': [''],
#  'resentment': ['towards', 'especially'],
#  'towards': ['your', 'my'],
#  'your': ['family',
#   'mind',
#   '',
#   'wealth',
#   'butt',
#   'mom',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'coworkers',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame',
#   'inner',
#   'secrets',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers',
#   'fingers',
#   'first',
#   '',
#   '',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg',
#   'life',
#   'doctors',
#   'body',
#   'nipples'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind': ['they', 'its', 'again'],
#  'whole': ['lives', 'manipulation', 'new', 'foods', 'foods', 'thing'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': [''],
#  'them': ['they', 'theyre', '', 'nothing', 'once', 'they', 'up'],
#  'hpv': ['yet', 'ok', 'yet', 'because', '', 'either', 'will', 'very'],
#  'peace': ['at', '', 'sign'],
#  'at': ['night',
#   'home',
#   'this',
#   '',
#   '',
#   'golden',
#   'any',
#   'how',
#   'all',
#   '',
#   'home',
#   'that',
#   'that',
#   '',
#   'work',
#   '',
#   '',
#   '',
#   '',
#   'life',
#   'first',
#   'home',
#   'any',
#   'my',
#   'fresh',
#   'some',
#   'my',
#   'work',
#   'him',
#   'his'],
#  'night': ['everybody', 'you', '', 'everybody'],
#  'has': ['hpv',
#   'it',
#   'it',
#   'hpv',
#   'hosted',
#   'even',
#   'made',
#   '',
#   '',
#   'had',
#   ''],
#  'ok': ['everybody',
#   'come',
#   'im',
#   'that',
#   'so',
#   'you',
#   '',
#   'i',
#   'because',
#   'you',
#   'so',
#   'are',
#   'cause',
#   'we',
#   'i',
#   'old',
#   'do',
#   'when',
#   '',
#   'when',
#   'its',
#   'when',
#   '',
#   '',
#   'they',
#   'are'],
#  'it': ['its',
#   'if',
#   'yet',
#   'you',
#   'its',
#   'might',
#   'was',
#   'was',
#   'all',
#   'was',
#   'when',
#   'cost',
#   'was',
#   'could',
#   'was',
#   'on',
#   'happened',
#   'happened',
#   'you',
#   'can',
#   'you',
#   'on',
#   'dont',
#   'second',
#   'was',
#   'you',
#   'so',
#   'came',
#   'on',
#   'on',
#   'as',
#   'so',
#   'we',
#   'for',
#   '',
#   'basically',
#   '',
#   'backfired',
#   'echo',
#   '',
#   '',
#   '',
#   'up',
#   'up',
#   'interesting',
#   '',
#   'before',
#   'tonight',
#   'that',
#   'might',
#   'when',
#   'up',
#   'was',
#   '',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'just',
#   'made',
#   'gets',
#   'tells',
#   'was',
#   'was',
#   'i',
#   'so',
#   'when',
#   'as',
#   'very',
#   'im',
#   'makes',
#   'takes',
#   'also',
#   'easier',
#   'was',
#   'different',
#   'up',
#   'thats',
#   'all',
#   'turns',
#   'how'],
#  'come': ['out', '', 'out', 'up', 'out', 'out', 'home', 'with', 'out'],
#  'out': ['already',
#   '',
#   'there',
#   '',
#   'they',
#   '',
#   'they',
#   'at',
#   'about',
#   'down',
#   '',
#   '',
#   '',
#   'first',
#   'that',
#   '',
#   'its',
#   'like',
#   '',
#   '',
#   'when',
#   'at',
#   'they',
#   'about',
#   '',
#   'yet',
#   '',
#   '',
#   'hes'],
#  'already': ['everybody', 'see', 'so', 'see'],
#  'if': ['you',
#   '',
#   'it',
#   'he',
#   '',
#   'you',
#   'you',
#   'i',
#   'youre',
#   'you',
#   'you',
#   'you',
#   'i',
#   'you',
#   'its',
#   'im',
#   'i',
#   'he',
#   'you',
#   'i',
#   'i'],
#  'youre': ['',
#   '',
#   'busy',
#   'with',
#   '',
#   'like',
#   'too',
#   'like',
#   'about',
#   'paranoid',
#   'like',
#   '',
#   'not',
#   'really',
#   'scared',
#   'married',
#   'gonna',
#   'fucking',
#   '',
#   'bossy',
#   'supposed',
#   '',
#   'eating',
#   'gonna',
#   'gonna',
#   '',
#   '',
#   'having',
#   'gonna',
#   ''],
#  'fucking': ['loser', 'housewife', 'different', 'baby', 'baby'],
#  'loser': ['all'],
#  'all': ['right',
#   'about',
#   '',
#   'your',
#   'came',
#   'required',
#   'because',
#   'this',
#   'right',
#   'his',
#   '',
#   '',
#   '',
#   'up',
#   'fucked',
#   'red',
#   'you',
#   'that',
#   '',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day',
#   'over',
#   'day',
#   '',
#   'sorts',
#   '',
#   'your',
#   'hes',
#   'squirmy',
#   'right',
#   '',
#   '',
#   'my',
#   'these',
#   '',
#   'know',
#   '',
#   '',
#   '',
#   'day',
#   'you',
#   'good',
#   '',
#   '',
#   'backed',
#   '',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off'],
#  'thats': ['what',
#   'gonna',
#   'right',
#   'what',
#   'not',
#   'where',
#   'right',
#   'like',
#   'how',
#   'how',
#   'not',
#   'right',
#   'gonna',
#   'why',
#   '',
#   'when',
#   'not',
#   'hilarious',
#   '',
#   '',
#   'cool',
#   'not',
#   'so',
#   'shit',
#   'right',
#   'so',
#   'like',
#   'my',
#   'why',
#   '',
#   'enough',
#   '',
#   'not'],
#  'says': ['about', 'boo', 'please', ''],
#  'about': ['you',
#   'how',
#   '',
#   'him',
#   '',
#   'vietnamese',
#   'it',
#   'supporting',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   '',
#   '',
#   'money',
#   'anal',
#   '',
#   'im',
#   'that',
#   '',
#   '',
#   '',
#   'it',
#   'giving',
#   'childbirth',
#   'all'],
#  'lot': ['',
#   'this',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'i',
#   'more',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'more',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  'men': ['dont', 'its', 'are', 'are', 'no', 'we', 'as'],
#  'undetectable': [''],
#  'really': ['fucked',
#   'im',
#   'its',
#   'work',
#   'meant',
#   'you',
#   'scared',
#   'i',
#   'am',
#   'take',
#   'am',
#   'hot'],
#  'fucked': ['up', '', 'up', 'so'],
#  'ghost': ['that'],
#  'inside': ['mens', 'horrible', 'i', ''],
#  'mens': ['bodies'],
#  'bodies': ['', 'my'],
#  'boo': [''],
#  'womens': ['bodies', 'intuition'],
#  'doctor': ['told', 'right', 'your', 'says', 'appointments'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'one': ['', '', '', '', 'person', 'i', '', 'she', '', 'who'],
#  'two': ['strains', 'homeless', 'days', 'latina', 'sacks', 'weeks'],
#  'strains': [''],
#  'either': ['i', 'im'],
#  'kind': ['thats', 'where', '', '', '', ''],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'upside'],
#  'into': ['cervical',
#   '',
#   '',
#   '',
#   '',
#   'banana',
#   '',
#   '',
#   '',
#   '',
#   'pleasure',
#   '',
#   'my',
#   'your',
#   '',
#   ''],
#  'cervical': ['cancer'],
#  'cancer': ['or'],
#  'body': ['will', '', 'hair', '', 'odor', 'was', 'when', 'where'],
#  'will': ['heal', 'also', 'also', 'you', 'always', 'be', 'have', 'commend'],
#  'heal': ['itself', 'from'],
#  'itself': ['very'],
#  'helpful': ['this'],
#  'basically': ['either', 'just', 'like'],
#  'die': ['or', '', 'dont', 'but', 'we', 'especially', 'were', 'why'],
#  'presence': [''],
#  'wolverine': ['bitches'],
#  'bitches': ['well', 'i'],
#  'well': ['find', 'with', 'i', 'see', 'asian'],
#  'find': ['outum', '', 'ways', '', 'it'],
#  'outum': ['i'],
#  'also': ['tell',
#   'disappear',
#   'got',
#   'last',
#   'hes',
#   'dont',
#   'decided',
#   'takes'],
#  'kindle': [''],
#  'turning': ['into', 'into'],
#  'selfhelp': ['library'],
#  'library': ['im'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   '',
#   'kissing',
#   'ask',
#   'authentic',
#   'recognize',
#   'doing',
#   '',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   '',
#   'again',
#   'rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'ok',
#   'fuckin',
#   'because',
#   'doing',
#   'there',
#   'gonna',
#   'like',
#   ''],
#  'interested': ['', ''],
#  'books': ['like'],
#  'fifty': ['shades'],
#  'shades': [''],
#  'grey': ['ok'],
#  'lifechanging': ['magic'],
#  'magic': [''],
#  'tidying': ['up'],
#  'how': ['',
#   'can',
#   'can',
#   'proposals',
#   'did',
#   'rotten',
#   'offstage',
#   'we',
#   '',
#   'much',
#   'invincible',
#   '',
#   'theres',
#   'it',
#   'did',
#   'did'],
#  'declutter': ['my'],
#  'home': ['', '', '', 'all', '', 'chapping', '', 'together'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['', ''],
#  'success': ['thats'],
#  'around': ['im', 'help', 'together', 'all', 'they', '', '', 'by'],
#  'horrible': ['person', 'but', 'toilet'],
#  'person': ['im', 'you–', 'for'],
#  'happy': ['with'],
#  'am': ['how', 'seven', 'imma', 'already', 'not', 'mad'],
#  'help': ['me', 'mei', 'her', 'you', 'as'],
#  'tony': ['robbins'],
#  'robbins': ['help'],
#  'mei': ['have'],
#  'hoarding': ['problem', 'goes', 'problem'],
#  'problem': ['which', 'because'],
#  'which': ['im',
#   '',
#   '',
#   'means',
#   'would',
#   '',
#   'means',
#   'their',
#   '',
#   '',
#   'hes',
#   'i',
#   '',
#   '',
#   '',
#   'means',
#   'subsequently'],
#  'hoping': ['', 'that'],
#  'center': [''],
#  'other': ['problems', 'homeless', 'because', 'day', 'you', 'shitty'],
#  'problems': ['im'],
#  'goes': ['away', 'down'],
#  'away': ['', 'anything', 'from', '', 'at'],
#  'disappear': ['i', 'thats', ''],
#  'mom': ['', 'it', 'got', 'my', '', 'i', '', 'people'],
#  'from': ['',
#   '',
#   '',
#   '',
#   '',
#   'pier',
#   'harvard',
#   '',
#   '',
#   'having',
#   'having',
#   '',
#   'this',
#   'pedestrians',
#   'their',
#   '',
#   'thats',
#   'holding',
#   'bacteria',
#   'harvard'],
#  'third': ['world', 'grade', 'world'],
#  'world': ['country', '♪it', 'with', 'country'],
#  'country': ['', '', ''],
#  'she': ['taught',
#   'refused',
#   'dont',
#   'was',
#   'wrote',
#   'knows',
#   '',
#   'doesnt',
#   'was',
#   'said'],
#  'taught': ['me'],
#  'never': ['throw', 'know', 'know', 'finish', 'finish', 'called', 'go'],
#  'throw': ['away', 'up', 'up'],
#  'anything': ['because', 'about', 'so', 'bitch', 'look'],
#  'dictators': ['gonna'],
#  'overtake': [''],
#  'snatch': ['all'],
#  'wealth': ['so'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'it', 'onto'],
#  'onto': ['that', '', 'his'],
#  'retainer': ['from'],
#  'grade': ['cause', 'it'],
#  'might': ['come', 'need', 'mean'],
#  'handy': ['as'],
#  'as': ['',
#   '',
#   'an',
#   'women',
#   'much',
#   'they',
#   '',
#   'many',
#   'possible',
#   '',
#   'freaky',
#   'me',
#   '',
#   'old',
#   'her',
#   'wet',
#   'it',
#   'pentup',
#   'angry',
#   'possible',
#   'leverage',
#   'it'],
#  'shovel': ['when'],
#  'busy': ['stuffing', '', 'so', 'makin'],
#  'stuffing': ['gold'],
#  'gold': ['up'],
#  'butt': ['', 'hole', 'with', 'hole', 'cheeks', 'all', 'i', 'hole'],
#  'running': ['away'],
#  'communiststhe': ['last'],
#  'last': ['time', 'forever', 'boyfriend', 'time', 'year', 'boyfriend', 'year'],
#  'time': ['i',
#   '',
#   'he',
#   'shitting',
#   '',
#   'i',
#   'i',
#   'that',
#   'so',
#   'i',
#   'all',
#   'you',
#   'you',
#   '',
#   'it',
#   'like',
#   '',
#   ''],
#  'was': ['at',
#   'trying',
#   'like',
#   'so',
#   'this',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'that',
#   'attending',
#   'like',
#   '',
#   'like',
#   'living',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'cuban',
#   'like',
#   'like',
#   'like',
#   'legit',
#   'gonna',
#   'ready',
#   'ripe',
#   'rotten',
#   'free',
#   'like',
#   'you',
#   'like',
#   'like',
#   'oh',
#   'like',
#   'very',
#   'like',
#   'magicala',
#   '',
#   'sliced',
#   'sliced',
#   'like',
#   'like',
#   'gonna',
#   'starting',
#   'just',
#   'so',
#   '',
#   'ok',
#   'clearly',
#   'that',
#   'easter',
#   'like',
#   'so',
#   'about',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   '',
#   'like',
#   'like',
#   ''],
#  'san': ['francisco', 'francisco'],
#  'francisco': ['i', 'when'],
#  'trying': ['', '', '', '', '', '', '', ''],
#  'her': ['get',
#   '',
#   'book',
#   'lululemon',
#   'butt',
#   'there',
#   'its',
#   'nipples',
#   'pussy',
#   'white',
#   'mexican',
#   '',
#   'i'],
#  'rid': [''],
#  'ever': ['do', 'actually', 'happened'],
#  'do': ['that',
#   'know',
#   'fancy',
#   'yoga',
#   'ayahuasca',
#   'silent',
#   'shit',
#   'makes',
#   'it',
#   'it',
#   'anything',
#   'it',
#   'anything',
#   'you',
#   'write',
#   'that',
#   'whatever',
#   'what',
#   'you',
#   'that',
#   'all',
#   'anal',
#   'it',
#   '',
#   'itsheryl',
#   'get',
#   'whatever',
#   'this',
#   'that',
#   'it',
#   'you',
#   '',
#   'some',
#   'whatever',
#   'for',
#   'shit',
#   'mushrooms',
#   '',
#   'it',
#   'you'],
#  'worst': ['experience', 'thing'],
#  'experience': ['', 'some'],
#  'life': ['it', 'i', 'you', '', '', 'right'],
#  'emotional': ['we', 'about'],
#  'were': ['screaming',
#   'all',
#   '',
#   'hipsters',
#   'getting',
#   'done',
#   'both',
#   'like',
#   'dumb',
#   'too',
#   'expected',
#   'so',
#   'like',
#   'discouraging',
#   'like',
#   'such',
#   'trying',
#   'like',
#   '',
#   'alarmingly',
#   'suppositories',
#   'trying',
#   'like',
#   'not',
#   'hippies',
#   ''],
#  'screaming': [''],
#  'fighting': [''],
#  'yelling': [''],
#  'came': ['', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['', ''],
#  'let': ['go', 'two', 'me', 'it', 'me', 'their'],
#  'texas': ['instruments'],
#  'instruments': [''],
#  'manual': ['', 'she', ''],
#  'calculator': ['', '', 'that'],
#  'those': ['', 'brains', 'comments', 'green', 'old', 'doctor', 'crazy'],
#  'under': [''],
#  'probably': ['dont', 'pinterested', 'one', 'looked'],
#  'bamboozled': ['my'],
#  'generation': ['we', 'you'],
#  'required': [''],
#  'buy': ['it'],
#  'eight': ['grade'],
#  'cost': ['like'],
#  'judy': ['jetsons'],
#  'jetsons': ['laptop'],
#  'laptop': ['from'],
#  'future': ['all', 'cause'],
#  'graph': ['it'],
#  'tesla': [''],
#  'need': ['this',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'children',
#   '',
#   'you',
#   ''],
#  'clean': ['all'],
#  'be': ['',
#   '',
#   'nice',
#   'with',
#   'racist',
#   'exfoliated',
#   'providing',
#   'made',
#   'no',
#   'like',
#   'like',
#   'like',
#   '',
#   'all',
#   'abused',
#   'roughed',
#   'out',
#   'sure',
#   'out',
#   '',
#   'able',
#   'like',
#   'so',
#   'there',
#   'there',
#   'one',
#   'its',
#   'that',
#   'im–',
#   'storyboarding',
#   'able',
#   'like',
#   'as',
#   'like',
#   'like',
#   'pregnant',
#   'this',
#   'seven',
#   'asked',
#   'considered',
#   'considered',
#   'one'],
#  'procrastinator': ['anymore'],
#  'anymore': ['because', 'i', 'i', 'ive', 'holds', '', 'since', 'im', 'im'],
#  'according': ['', ''],
#  'deepakoprah': ['thats'],
#  'way': ['for', 'out', '', '', 'more'],
#  'successi': ['grew'],
#  'grew': ['up', 'up', 'up', 'up'],
#  'past': ['year', 'year'],
#  'married': ['yeah', 'last', 'im', 'youre', 'was', 'all'],
#  'yeah': ['',
#   'you',
#   'yes',
#   'which',
#   'like',
#   'never',
#   'its',
#   'thats',
#   'thats',
#   'let',
#   '',
#   'where',
#   'i'],
#  'man': ['who', 'i', '', 'has', '', 'at', 'all', ''],
#  'who': ['now',
#   '',
#   'like',
#   'like',
#   'are',
#   'wrote',
#   'are',
#   'have',
#   'recycles',
#   'are',
#   'have',
#   'else',
#   'tries',
#   'trapped'],
#  'lucky': ['guy', 'girl'],
#  'guy': ['he', '', 'whos'],
#  'he': ['gave',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'grew',
#   'grew',
#   'didnt',
#   'met',
#   'took',
#   'was',
#   'was',
#   'doesnt',
#   'becomes',
#   'proposed',
#   'got',
#   'know',
#   'saw',
#   'graduated',
#   'was',
#   'refused',
#   'puts',
#   'had',
#   'does',
#   'would',
# ...
#  'stuff': ['like', 'like'],
#  'voting': [''],
#  'recycling': [''],
#  'disturbing': ['documentaries'],
#  'documentaries': ['they'],
#  'introduce': ['you'],
#  'hot': ['hookin', 'you', 'you'],
#  'hookin': ['up'],
#  'mean': ['nothing', 'were', 'that', 'pay'],
#  'nothing': ['makes', 'they', 'for'],
#  'makes': ['me', 'me', 'sense'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   '',
#   'women',
#   'handsome'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy': ['oh', 'needs', '', 'was', ''],
#  'absorbing': ['all'],
#  'privilege': [''],
#  'entitlement': ['you'],
#  'through': ['', 'southeast', '', '', 'it', ''],
#  'money': ['hole', 'they', 'you', 'if', 'you', 'paid'],
#  'hole': ['', 'its', 'feels', ''],
#  'vulnerable': ['down'],
#  'down': ['there',
#   'its',
#   'i',
#   'i',
#   'there',
#   'your',
#   'immediately',
#   '',
#   'so',
#   'people',
#   'with'],
#  'crush': ['your', 'those', 'while'],
#  'head': ['at', 'first', 'shredding', '', 'for'],
#  'moment': ['white', '', 'you'],
#  'kill': ['you', 'me'],
#  'brains': ['colonize'],
#  'colonize': [''],
#  'colonizer': ['you'],
#  'knowbut': ['i'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'its',
#   '',
#   'about',
#   'thats',
#   'so',
#   'im'],
#  'marriage': ['it', 'i', 'because'],
#  'nice': ['', 'we'],
#  'somebody': ['', 'closes', 'closes'],
#  'own': ['race', 'goddamn'],
#  'race': [''],
#  'advantage': [''],
#  'racist': ['together'],
#  'say': ['whatever', '', 'you', 'you', 'be'],
#  'whatever': ['you', '', 'they', 'you', ''],
#  'explain': ['shit'],
#  'halffilipino': ['halfjapanese', ''],
#  'halfjapanese': ['im', ''],
#  'halfchinese': ['', ''],
#  'halfvietnamese': ['', 'so'],
#  'spend': [''],
#  'percent': ['', '', 'spoken'],
#  'our': ['time',
#   'first',
#   'buddha',
#   'careers',
#   'job',
#   'day',
#   'society',
#   'first'],
#  'shitting': ['on'],
#  'korean': ['people'],
#  'amazing': ['its'],
#  'love': ['', '', 'it', 'my', 'it', ''],
#  'built': ['on'],
#  'knowmy': ['last', 'husband'],
#  'boyfriend': ['was', 'because'],
#  'cuban': [''],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'i',
#   'crash',
#   'simultaneously',
#   'explode',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'mexican': ['people', 'asianamerican', 'friends'],
#  'guys': ['arent', 'know', 'about', 'need', 'had', 'can', 'i', 'doin'],
#  'arent': ['mexican'],
#  'underrated': ['i'],
#  'why': ['people',
#   'you',
#   'else',
#   'you',
#   'are',
#   'are',
#   'dont',
#   'were',
#   'im',
#   '',
#   'else'],
#  'sexiest': ['asian', 'they'],
#  'hair': ['from'],
#  'neck': ['down', ''],
#  'making': ['love'],
#  'dolphin': ['oh'],
#  'smooth': ['just'],
#  'slip': [''],
#  'slide': ['just'],
#  'black': ['fish', 'dont', 'friends', 'friends'],
#  'fish': ['tilikum'],
#  'tilikum': ['all'],
#  'bed': ['every', 'women'],
#  'every': ['night',
#   'day',
#   'single',
#   'day',
#   'day',
#   'day',
#   'day',
#   'time',
#   'single',
#   'time'],
#  'oohwee': ['you'],
#  'mess': ['with', 'theres'],
#  'jewish': ['dude', 'male'],
#  'afterwards': ['its', '', '', '', 'i', ''],
#  'red': ['', 'light'],
#  'inflamed': [''],
#  'ask': ['', 'for'],
#  'exfoliated': ['today'],
#  'today': ['this'],
#  'jdate': ['more'],
#  'loofah': ['date'],
#  'thanks': ['for'],
#  'rug': ['burn'],
#  'burn': ['avi', 'out'],
#  'avi': [''],
#  'odor': ['none'],
#  'none': ['they', ''],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility': ['thats', ''],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['fromi', 'out', 'out', 'out', ''],
#  'fromi': ['think'],
#  'unspoken': ['understanding'],
#  'understanding': ['uh'],
#  'between': ['each', 'your'],
#  'each': ['other', 'other'],
#  'both': ['halffancy', 'total', 'are'],
#  'halffancy': ['asian'],
#  'halfjungle': ['asian'],
#  'difference': [''],
#  'fancy': ['asians', 'things'],
#  'asians': ['are', 'host', 'we'],
#  'chinese': ['', 'scrolls', 'ladies', 'ladies'],
#  'japanese': ['they'],
#  'host': ['olympics', 'diseases'],
#  'olympics': ['jungle'],
#  'jungle': ['asians'],
#  'diseases': ['its'],
#  'different': ['but', 'person', 'holes', 'people', 'its', ''],
#  'east': ['coast'],
#  'coast': ['going'],
#  'private': ['school', 'school', 'school'],
#  'playing': ['lacrosse', 'chess', 'dumb', 'candy'],
#  'lacrosse': ['uh'],
#  'learning': ['latin'],
#  'latin': [''],
#  'chess': [''],
#  'rugby': ['he'],
#  'filipino': ['carlton'],
#  'carlton': ['ok'],
#  'didnt': ['know', 'think', 'know', 'know'],
#  'vietnamese': ['people', 'i'],
#  'dates': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side'],
#  'side': ['', 'from', 'effect'],
#  'los': ['angeles'],
#  'angeles': ['called'],
#  'called': ['pho', 'lean', 'bossy'],
#  'pho': ['show'],
#  'show': ['he', 'off', 'i', 'him', 'signs', 'theres'],
#  'authentic': ['vietnamese', 'ok'],
#  'read': ['about'],
#  'yelp': ['i'],
#  'name': ['cause'],
#  'number': [''],
#  'second': ['', 'chance'],
#  'bathroom': ['if', 'would'],
#  'legit': [''],
#  'double': ['as', 'standard'],
#  'supply': ['closet'],
#  'closet': ['when'],
#  'gallons': [''],
#  'bleach': ['an'],
#  'atm': ['machine'],
#  'machine': [''],
#  'grandma': ['with', 'youre–'],
#  'glaucoma': ['napping'],
#  'napping': [''],
#  'corner': [''],
#  'wait': ['staff', ''],
#  'staff': ['here', ''],
#  'leave': ['this', 'without', 'you'],
#  'deaf': [''],
#  'emotionally': ['abusedi'],
#  'abusedi': ['grew'],
#  'total': ['like'],
#  'big': ['hippies', 'fantasy', 'impact', 'like'],
#  'hippies': ['too', 'id'],
#  'backpack': ['through'],
#  'southeast': ['asia'],
#  'asia': ['we'],
#  'yoga': ['we'],
#  'ayahuasca': ['ceremonies'],
#  'ceremonies': ['we'],
#  'silent': ['meditation'],
#  'retreats': ['thats'],
#  'pay': ['', 'for'],
#  'shut': ['up', '', 'up', ''],
#  'weekend': ['we'],
#  'glutenfree': ['which'],
#  'means': ['we', 'i', '', 'ok', 'youre'],
#  'bread': ['that', 'thats', 'thats'],
#  'tastes': ['like', 'when'],
#  'freerange': ['chewbacca'],
#  'chewbacca': ['we'],
#  'lesbian': ['bread'],
#  'thousand': ['percent'],
#  'daily': ['fiber', 'basis', 'basis'],
#  'fiber': [''],
#  'spoken': ['word'],
#  'word': ['poetry', 'bossy', 'bossy'],
#  'poetry': ['when'],
#  'queef': [''],
#  'shitty': ['poem', 'dads', 'mom'],
#  'poem': ['about'],
#  'supporting': ['caitlyn'],
#  'caitlyn': ['jenner'],
#  'jenner': ['or'],
#  'funny': ['right', 'man'],
#  'sometimes': ['all'],
#  'hippydippy': ['shit'],
#  'doing': ['an', 'anything', 'jack', 'itnow'],
#  'impression': [''],
#  'scrolls': ['up'],
#  'wall': ['', 'that'],
#  'neither': [''],
#  'us': ['know', '', ''],
#  'seems': ['', ''],
#  'buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'pier': [''],
#  'imports': ['that'],
#  'providing': ['some'],
#  'some': ['good', 'risk', 'useful', 'lame', 'point', ''],
#  'good': ['feng', 'we', '', 'night'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'househim': [''],
#  'four': ['years', 'days'],
#  'years': ['', '', 'ive', 'old', 'old'],
#  'i–': ['i', 'i–', 'i', 'i'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose': ['because', ''],
#  'pressuring': ['him'],
#  'wacky': ['womens'],
#  'intuition': ['thats'],
#  'proposals': ['really'],
#  'work': ['ok',
#   'anymore',
#   'anymore',
#   'anymore',
#   'when',
#   'at',
#   'because',
#   'on',
#   'anymore',
#   'anymoreim',
#   'i',
#   'we'],
#  'incept': [''],
#  'idea': ['into'],
#  'mans': ['head', 'eye'],
#  'passively': [''],
#  'doesnt': ['get', 'see', 'have', 'have', 'believe'],
#  'message': ['extremely'],
#  'extremely': ['aggressively', 'itchy'],
#  'aggressively': ['you'],
#  'threaten': [''],
#  'without': ['ever'],
#  'actually': ['leaving'],
#  'leaving': ['because'],
#  'old': ['', 'as', 'chinese', 'chinese', 'asian', '', 'when'],
#  'late': [''],
#  'new': ['man', 'world'],
#  'start': ['', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again': ['so', '', 'its', 'i', 'but', 'because'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': [''],
#  'outta': ['him', 'nowhere'],
#  'becomes': ['weak'],
#  'weak': [''],
#  'caves': [''],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  'fine': ['will', 'by'],
#  'marry': ['me', 'him'],
#  'always': ['like', 'very', 'feel', 'catch', 'means', 'tell', 'wantedim'],
#  'proposed': ['it'],
#  'nowhere': ['', ''],
#  'look': ['he',
#   'at',
#   'at',
#   '',
#   'on',
#   'like',
#   'me',
#   'you',
#   'forward',
#   'like',
#   'like'],
#  'exact': ['ring'],
#  'ring': ['i'],
#  'wanted': ['how', '', 'him'],
#  'maybe': ['he', 'youll', 'because'],
#  'pinterest': ['page', 'page'],
#  'page': ['or', 'hes'],
#  'sent': [''],
#  'best': ['friend', 'you'],
#  'friend': ['that'],
#  'send': [''],
#  'pinterested': [''],
#  'engaged': ['on'],
#  'saturday': ['i'],
#  'bought': ['my', 'me', 'our'],
#  'dress': [''],
#  'following': ['tuesday'],
#  'tuesday': ['because'],
#  'tried': ['it', '', ''],
#  'ready': ['i'],
#  'ripe': ['i'],
#  'rotten': ['i', 'i'],
#  'banana': ['bread'],
#  'waspeople': ['are'],
#  'surprised': ['at'],
#  'offstage': ['with'],
#  'completely': ['different', 'im'],
#  'you–': ['like', 'that'],
#  'recognize': ['my', 'your'],
#  'personality': ['at'],
#  'soft': ['', 'serve'],
#  'nurturing': [''],
#  'domestic': ['weve'],
#  'weve': ['been'],
#  'ive': ['packed', 'been', 'been', 'asked', 'picked', 'been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day', 'night'],
#  'hed': ['become'],
#  'become': ['dependent', '', '', 'this', 'some'],
#  'dependent': ['on'],
#  'graduated': ['from', 'from'],
#  'feed': ['him'],
#  'goodness': [''],
#  'heart': ['i'],
#  'investment': [''],
#  'financial': ['future'],
#  'reading': ['that'],
#  'book': ['by', 'that', ''],
#  'sheryl': ['sandberg'],
#  'sandberg': ['shes', 'that'],
#  'shes': ['', 'not', 'retiredi', 'waiting', 'timing', 'busy', 'got', 'from'],
#  'coo': [''],
#  'facebook': [''],
#  'wrote': ['that', 'lean'],
#  'riled': ['up'],
#  'careers': ['talking'],
#  'talking': ['about', 'about', 'about'],
#  'should': ['challenge', 'not'],
#  'challenge': ['ourselves'],
#  'ourselves': [''],
#  'sit': ['at'],
#  'table': ['', '', 'i'],
#  'rise': [''],
#  'top': [''],
#  'lean': ['', '', ''],
#  'lie': ['down', ''],
#  'want': ['', 'they', 'their–', '', 'my', 'noah', 'i', 'for', '', 'your'],
#  'feminism': [''],
#  'job': ['used', 'we', 'at', 'most'],
#  'used': ['', '', 'it'],
#  'smart': ['thing'],
#  'continue': ['playing'],
#  'dumb': ['for', 'women'],
#  'century': ['', 'more'],
#  'guess': ['we', 'who'],
#  'stay': ['at', 'thats'],
#  'snacks': [''],
#  'watch': ['ellen', 'property', 'when', ''],
#  'ellen': ['cause'],
#  'stupid': [''],
#  'real': ['responsibility', 'boss', 'miracle'],
#  'bitch': ['shut', '', 'had'],
#  'ruined': ['it'],
#  'expected': [''],
#  'hear': ['', 'my', 'that'],
#  'phrase': ['doubleincome', 'black'],
#  'doubleincome': ['household'],
#  'household': ['i'],
#  'upset': ['with'],
#  'comments': [''],
#  'options': ['now', 'when'],
#  'free': ['unscheduled', '', 'activity'],
#  'unscheduled': ['unsupervised'],
#  'unsupervised': [''],
#  'most': ['importantly', 'strongheaded', '', 'likely', '', '', 'women'],
#  'importantly': ['sponsored'],
#  'sponsored': ['do'],
#  'shittier': ['food'],
#  'food': ['tastes'],
#  'earn': ['ita'],
#  'ita': ['lot'],
#  'walk': ['around'],
#  'theyll': ['get', 'be', 'get', 'be'],
#  'judgmental': ['about'],
#  'housewives': ['that', 'they', 'get', 'they', 'are', 'they'],
#  'street': [''],
#  'housewife': ['not', 'just', 'shes', 'financially'],
#  'walking': ['around', 'like'],
#  'massages': [''],
#  'lululemon': ['pants'],
#  'pants': ['im', 'at'],
#  'genius': ['shes'],
#  'retiredi': ['do'],
#  'write': ['for'],
#  'fresh': ['off', 'off'],
#  'boat': ['on', 'i'],
#  'abc': ['yeah'],
#  'great': ['show', 'writing', 'dad'],
#  'coworkers': ['its', 'gonna', 'blow', 'blow', ''],
#  'writing': ['staff', 'job'],
#  'terms': [''],
#  'jobs': ['its'],
#  'still': ['gotta', 'here'],
#  'office': ['every', 'every', 'housewives', 'toilet'],
#  'house': ['skin', 'hey'],
#  'skin': ['', 'every'],
#  'seat': ['they'],
#  'use': ['that', 'that', ''],
#  'toilet': ['paper', 'paper', 'paper', 'paper', 'paper', '', 'i', '', ''],
#  'paper': ['cover', 'that', 'that', 'thats', 'two'],
#  'cover': ['they'],
#  'times': [''],
#  'sadass': ['meal'],
#  'meal': ['they'],
#  'oneply': ['toilet'],
#  'purposely': ['make'],
#  'difficult': [''],
#  'pull': ['out'],
#  'try': ['', '', '', '', ''],
#  'ration': ['me'],
#  'communist': ['toilet'],
#  'effective': ['it'],
#  'dehydrates': ['your'],
#  'wiping': ['your', 'at', ''],
#  'desert': ['i'],
#  'literally': ['spat', 'trying'],
#  'spat': ['on'],
#  'days': ['ago', 'out', 'he', 'i'],
#  'ago': [''],
#  'macgyver': ['baby'],
#  'baby': ['wipe',
#   'theyll',
#   'that',
#   '',
#   'comes',
#   'hasnt',
#   'can',
#   'can',
#   'from'],
#  'wipe': [''],
#  'moisten': ['it'],
#  'backfired': ['cause'],
#  'fingers': ['broke',
#   'oh',
#   'afterwards',
#   'when',
#   'housewives',
#   'when',
#   'when',
#   'nature',
#   'are',
#   'like'],
#  'broke': ['through', 'up'],
#  'digitally': ['stimulated'],
#  'stimulated': ['more'],
#  'doo': ['doo', '', 'doo', 'all', 'doo', 'comes', 'doo', 'comes', 'doo', 'on'],
#  'finish': ['wiping', 'wiping', 'i', 'its'],
#  'rushed': ['cause'],
#  'paranoid': ['that'],
#  'shoes': ['underneath', 'its'],
#  'underneath': ['', ''],
#  'stall': [''],
#  'courtneys': ['listening'],
#  'listening': ['shes'],
#  'waiting': ['shes', 'for'],
#  'timing': ['me'],
#  'hurry': ['hurry', 'hurry', '', ''],
#  'feels': ['caked'],
#  'caked': [''],
#  'long': ['', 'they'],
#  'dare': ['scratch', 'you'],
#  'scratch': ['yourself', 'on', 'myself', '', 'sniff', 'whats', 'yourself'],
#  'yourself': ['your', 'do', 'all'],
#  'underwear': ['at', ''],
#  'end': [''],
#  'looks': ['like'],
#  'goonies': ['housewives'],
#  'muffle': ['their'],
#  'worry': ['about', 'cause'],
#  'velocity': ['with'],
#  'squeeze': [''],
#  'cheeks': ['together'],
#  'sure': ['that', 'that', 'all'],
#  'slow': [''],
#  'steady': ['pace'],
#  'pace': ['so'],
#  'unpredictable': ['noise'],
#  'noise': ['suddenly'],
#  'suddenly': ['escapes'],
#  'escapes': [''],
#  'brings': ['you'],
#  'deep': ['deep', 'shame'],
#  'shame': ['housewives', 'your', 'theyre'],
#  'blow': ['ass', 'ass', 'ass', ''],
#  'echo': [''],
#  'reverberate': [''],
#  'ends': [''],
#  'hallways': ['while'],
#  'while': ['watching', 'it', 'i', 'i'],
#  'watching': ['as', 'porn', 'porn'],
#  'netflix': ['on'],
#  'ipad': ['as'],
#  'boring': ['repressed', ''],
#  'repressed': ['shits'],
#  'shits': ['they'],
#  'listen': [''],
#  'podcasts': ['planet'],
#  'planet': ['money'],
#  'wantyou': ['know'],
#  'its–': ['its'],
#  'distracting': ['for'],
#  'lose': ['respect'],
#  'respect': ['for', 'you', 'me'],
#  'holds': ['any'],
#  'sort': [''],
#  'credence': ['i'],
#  'heard': ['one', 'you'],
#  'nerve': [''],
#  'bananas': ['i'],
#  'green': ['ballet'],
#  'ballet': ['flats'],
#  'flats': ['i'],
#  'togethermy': ['fatherinlaw'],
#  'fatherinlaw': ['had'],
#  'sitdown': ['with'],
#  'recently': ['um', 'we'],
#  'um': ['', 'yeah'],
#  'talk': ['', 'cause', 'im', 'about'],
#  'provide': ['your'],
#  'children': ['with', '', ''],
#  'same': ['kind', 'when'],
#  'privileged': ['childhood'],
#  'childhood': ['that'],
#  'telling': ['me'],
#  'conversation': ['you'],
#  'son': ['that', 'for'],
#  'understand': ['that'],
#  'earning': ['potential'],
#  'else': ['would', 'i', 'has', 'do'],
#  'choose': [''],
#  'rest': ['', ''],
#  'chose': [''],
#  'promise': [''],
#  'early': ['retirement', ''],
#  'retirement': [''],
#  'said': ['i', '', 'but'],
#  'meant': ['was'],
#  'dieting': ['anymore'],
#  'since': ['i', 'thats'],
#  'eating': ['fried', 'mango'],
#  'fried': ['chicken'],
#  'chicken': ['skin'],
#  'fulfilling': ['my'],
#  'destiny': ['which', 'ok'],
#  'circle': ['with'],
#  'eyelashes': ['like'],
#  'mrs': ['pacman'],
#  'pacman': ['just'],
#  'lets': ['redecoratei'],
#  'redecoratei': ['gave'],
#  'myself': ['when', 'every', 'underneath'],
#  '–': ['im', '', 'when', 'previously'],
#  'disgusting': ['pervert'],
#  'pervert': ['im', 'im'],
#  'gross': ['filthy'],
#  'filthy': ['animal'],
#  'animal': [''],
#  'started': ['watching'],
#  'porn': ['at', 'at'],
#  'young': ['age', 'age'],
#  'age': ['', ''],
#  'happens': ['when', 'for', 'because'],
#  'yyou': ['get'],
#  'sicker': ['', '', '', '', '', 'but'],
#  'images': ['you'],
#  'crave': ['get'],
#  'internet': ['will', 'would'],
#  'youi': ['broke'],
#  'idiot': ['dude'],
#  'realize': ['that'],
#  'went': ['on', ''],
#  'craigslist': ['', 'thats'],
#  'posted': ['tiny'],
#  'tiny': ['asian'],
#  'female': ['seeking', 'comic', 'comics', 'standup'],
#  'seeking': ['anal'],
#  'anal': ['', '', 'eventually', 'i'],
#  'crash': [''],
#  'male': ['heads', 'comics'],
#  'heads': [''],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'Suddenly escapes  audience are always catch up  youre like  fuck they like.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.
